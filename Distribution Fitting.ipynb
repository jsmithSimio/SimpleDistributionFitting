# %% [markdown]
# ## Simple Distribution Fitting
# Uses scipy stats package to fit sample data to several common distributions. Currently includes Uniform, Exponential, Triangular, Weibull, and Lognormal distributions.
#
# 2026-03-11
# <br>Jeff Smith

# %%
import pandas as pd
import numpy as np
from fit_dists import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read the csv file into a Pandas dataframe and show the first 5 rows.
csv_file = "data/OutputTable1.csv"
df = pd.read_csv(csv_file, skipinitialspace=True)
print(df.head())
# Out:
#    WeibullSample  NormalSample
# 0       0.523159     36.150143
# 1       0.513589     35.794137
# 2       0.323607     36.138261
# 3       0.534278     36.233329
# 4       0.529409     36.473155

# %%
# Choose a column, extract to a Numpy array, show the histogram.
column = "NormalSample"
data = df[column].to_numpy(dtype=float)
# Only 1 of the next two lines should be uncommented.
plt.hist(data);
#plt.hist(data, bins=20);

# %%
# Fit the distributions and show the fit report.
report = fit_dists(data, verbose=False)
print(report)
# Out:
# ---------------------------------------------------------------
# -- Descriptive Statistics -------------------------------------
#   n          : 1000
#   mean       : 35.6665
#   std (s)    : 0.483277
#   variance   : 0.233556
#   median     : 35.7043
#   skewness   : -0.18334
#   kurtosis   : -0.0568486  (excess)
#   min        : 34.0641
#   max        : 37.1885
# ---------------------------------------------------------------
# -- Distribution Fits ------------------------------------------
#
#   normal        : mu=35.6665,  sigma=0.483035
#                   KS=0.0343,  p=0.1856  [good fit]
#                   Simio: Random.Normal(35.6665, 0.483035)
#
#   uniform       : a (loc)=34.0641,  b (loc+scale)=37.1885
#                   KS=0.2116,  p=0.0000  [poor fit]
#                   Simio: Random.Uniform(34.0641, 37.1885)
#
#   exponential   : loc=34.0641,  scale (1/lambda)=1.60234,  lambda=0.624086
#                   KS=0.3557,  p=0.0000  [poor fit]
#                   Simio: Random.Exponential(1.60234)
#
#   triangular    : a (min)=34.0578,  b (max)=37.1939,  c (mode)=35.7435
#                   KS=0.0953,  p=0.0000  [poor fit]
#                   Simio: Random.Triangular(34.0578, 35.7435, 37.1939)
#
#   weibull       : k (shape)=77.758,  lambda (scale)=35.9007,  loc=0
#                   KS=0.0459,  p=0.0284  [poor fit]
#                   Simio: Random.Weibull(77.758, 35.9007)
#
#   lognormal     : mu_ln=3.57412,  sigma_ln=0.0135629,  loc=0
#                   KS=0.0369,  p=0.1284  [good fit]
#                   Simio: Random.Lognormal(3.57412, 0.0135629)
# ---------------------------------------------------------------
