# %% [markdown]
# ## Simple Distribution Fitting
# Uses scipy stats package to fit sample data to several common distributions.
#
# 2026-03-11
# <br>Jeff Smith

# %%
import pandas as pd
import numpy as np
from fit_dists import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_file = "data/OutputTable1.csv"
df = pd.read_csv(csv_file, skipinitialspace=True)
print(df.head())
# Out:
#    WeibullSample  NormalSample
# 0       0.523159     36.150143
# 1       0.513589     35.794137
# 2       0.323607     36.138261
# 3       0.534278     36.233329
# 4       0.529409     36.473155

# %%
column = "WeibullSample"
data = df[column].to_numpy(dtype=float)
plt.hist(data);
#plt.hist(data, bins=20);

# %%
report = fit_dists(data, verbose=False)
print(report)
# Out:
# ---------------------------------------------------------------
# -- Descriptive Statistics -------------------------------------
#   n          : 1000
#   mean       : 0.473138
#   std (s)    : 0.0594713
#   variance   : 0.00353684
#   median     : 0.482594
#   skewness   : -0.731834
#   kurtosis   : 0.533732  (excess)
#   min        : 0.243425
#   max        : 0.608505
# ---------------------------------------------------------------
# -- Distribution Fits ------------------------------------------
#   normal        : mu=0.473138,  sigma=0.0594416
#                   KS=0.0729,  p=0.0000  [poor fit]
#                   Simio: Random.Normal(0.473138, 0.0594416)
#   uniform       : a (loc)=0.243425,  b (loc+scale)=0.608505
#                   KS=0.3161,  p=0.0000  [poor fit]
#                   Simio: Random.Uniform(0.243425, 0.608505)
#   exponential   : loc=0.243425,  scale (1/lambda)=0.229713,  lambda=4.35326
#                   KS=0.3811,  p=0.0000  [poor fit]
# ...
